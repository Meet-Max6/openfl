# %% [markdown]
# # FederatedRuntime 101: Quickstart with MNIST

# %% [markdown]
# Welcome to the first **FederatedRuntime** Tutorial !
# This tutorial demonstrates how to deploy Federated-Learning experiment based on workflow interface on a distributed computing infrastructure.
#
# Data scientists often start by developing and fine-tuning Federated machine-learning models in a local environment before transitioning to a Federated setup. OpenFL supports this methodology and the Tutorial guides the user through the following steps:
# - **Simulate** a Federated Learning experiment locally using `LocalRuntime`
# - **Deploy** this experiment on Federated Infrastructure using `FederatedRuntime` from from a familiar Jupyter notebook environment
#
# **Key Features covered**:
# 1. **Simulate** Federated Learning experiment using `LocalRuntime`. Explore [101 MNIST](https://github.com/securefederatedai/openfl/blob/develop/openfl-tutorials/experimental/workflow/101_MNIST.ipynb) for insights
# 2. Enable creation of workspace content by annotating Jupyter notebook with export directives. Explore [1001 Workspace Creation from JupyterNotebook](https://github.com/securefederatedai/openfl/blob/develop/openfl-tutorials/experimental/workflow/1001_Workspace_Creation_from_JupyterNotebook.ipynb) for insights
# 3. **Deploy** the experiment on Federated infrastructure (Director and Envoy nodes) using `FederatedRuntime`.
#    NOTE: Participants in the Federation should be launched using the steps described in [README.md](https://github.com/securefederatedai/openfl/blob/develop/openfl-tutorials/experimental/workflow/FederatedRuntime/101_MNIST/README.md) before deploying the experiment.
#
# Let's get started !

# %% [markdown]
# ### Getting Started

# %% [markdown]
# We begin by specifying the module where cells marked with the `#| export` directive will be automatically exported. The export directive is used to identify specific code cells in the Jupyter notebook that should be included in the generated python module. This python module is required to distribute the FL experiment.
#
# The `#| default_exp` experiment directive in the following cell sets the name of the python module as `experiment`. This name can be customized according to the user’s requirements and preferences.

# %%
#| default_exp experiment

# %% [markdown]
# Once we have specified the name of the module, subsequent cells of the notebook need to be *appended* by the `#| export` directive as shown below. User should ensure that *all* the notebook functionality required in the Federated Learning experiment is included in this directive

# %% [markdown]
# ### Installing Pre-requisites
# We start by installing OpenFL and dependencies of the workflow interface. These dependencies are exported and become requirements for the Federated Learning Environment

# %%
#| export

# !pip install git+https://github.com/securefederatedai/openfl.git
# !pip install -r ../../../workflow_interface_requirements.txt
# !pip install torch==2.3.1
# !pip install torchvision==0.18.1
# !pip install -U ipywidgets
# Out:
# Collecting git+https://github.com/securefederatedai/openfl.git
#   Cloning https://github.com/securefederatedai/openfl.git to /tmp/pip-req-build-3p5ljxmx
#   Running command git clone --filter=blob:none --quiet https://github.com/securefederatedai/openfl.git /tmp/pip-req-build-3p5ljxmx
#   Resolved https://github.com/securefederatedai/openfl.git to commit d8a00c85e0c74a1d2f7218a19670bfd9d35d2976
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Installing backend dependencies ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: click in /home/meet/miniconda3/envs/myenv_openfl/lib/python3.10/site-packages (from openfl==1.9.0.dev0) (8.2.0)
# Requirement already satisfied: psutil in /home/meet/.local/lib/python3.10/site-packages (from openfl==1.9.0.dev0) (7.0.0)
# Requirement already satisfied: pyyaml in /home/meet/miniconda3/envs/myenv_openfl/lib/python3.10/site-packages (from openfl==1.9.0.dev0) (6.0.2)
# Requirement already satisfied: rich in /home/meet/.local/lib/python3.10/site-packages (from openfl==1.9.0.dev0) (14.0.0)
# Requirement already satisfied: dynaconf in /home/meet/.local/lib/python3.10/site-packages (from openfl==1.9.0.dev0) (3.2.10)
# Requirement already satisfied: tqdm in /home/meet/.local/lib/python3.10/site-packages (from openfl==1.9.0.dev0) (4.67.1)
# Requirement already satisfied: numpy in /home/meet/.local/lib/python3.10/site-packages (from openfl==1.9.0.dev0) (2.2.4)
# Requirement already satisfied: requests>=2.32.0 in /home/meet/.local/lib/python3.10/site-packages (from openfl==1.9.0.dev0) (2.32.3)
# Requirement already satisfied: cloudpickle in /home/meet/.local/lib/python3.10/site-packages (from openfl==1.9.0.dev0) (3.1.1)
# Requirement already satisfied: cryptography in /home/meet/miniconda3/envs/myenv_openfl/lib/python3.10/site-packages (from openfl==1.9.0.dev0) (44.0.3)
# Requirement already satisfied: pandas in /home/meet/.local/lib/python3.10/site-packages (from openfl==1.9.0.dev0) (2.2.3)
# Requirement already satisfied: scikit-learn in /home/meet/.local/lib/python3.10/site-packages (from openfl==1.9.0.dev0) (1.6.1)
# Requirement already satisfied: flatten_json in /home/meet/.local/lib/python3.10/site-packages (from openfl==1.9.0.dev0) (0.1.14)
# Requirement already satisfied: tensorboardX in /home/meet/.local/lib/python3.10/site-packages (from openfl==1.9.0.dev0) (2.6.2.2)
# Requirement already satisfied: protobuf<6.0.0,>=4.21 in /home/meet/.local/lib/python3.10/site-packages (from openfl==1.9.0.dev0) (5.29.4)
# Requirement already satisfied: grpcio<1.66.0,>=1.56.2 in /home/meet/.local/lib/python3.10/site-packages (from openfl==1.9.0.dev0) (1.65.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/meet/.local/lib/python3.10/site-packages (from requests>=2.32.0->openfl==1.9.0.dev0) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /home/meet/miniconda3/envs/myenv_openfl/lib/python3.10/site-packages (from requests>=2.32.0->openfl==1.9.0.dev0) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/meet/miniconda3/envs/myenv_openfl/lib/python3.10/site-packages (from requests>=2.32.0->openfl==1.9.0.dev0) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /home/meet/miniconda3/envs/myenv_openfl/lib/python3.10/site-packages (from requests>=2.32.0->openfl==1.9.0.dev0) (2025.4.26)
# Requirement already satisfied: cffi>=1.12 in /home/meet/miniconda3/envs/myenv_openfl/lib/python3.10/site-packages (from cryptography->openfl==1.9.0.dev0) (1.17.1)
# Requirement already satisfied: six in /home/meet/miniconda3/envs/myenv_openfl/lib/python3.10/site-packages (from flatten_json->openfl==1.9.0.dev0) (1.17.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/meet/.local/lib/python3.10/site-packages (from pandas->openfl==1.9.0.dev0) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /home/meet/miniconda3/envs/myenv_openfl/lib/python3.10/site-packages (from pandas->openfl==1.9.0.dev0) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /home/meet/.local/lib/python3.10/site-packages (from pandas->openfl==1.9.0.dev0) (2025.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /home/meet/.local/lib/python3.10/site-packages (from rich->openfl==1.9.0.dev0) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /home/meet/.local/lib/python3.10/site-packages (from rich->openfl==1.9.0.dev0) (2.19.1)
# Requirement already satisfied: typing-extensions<5.0,>=4.0.0 in /home/meet/.local/lib/python3.10/site-packages (from rich->openfl==1.9.0.dev0) (4.13.2)
# Requirement already satisfied: scipy>=1.6.0 in /home/meet/.local/lib/python3.10/site-packages (from scikit-learn->openfl==1.9.0.dev0) (1.15.2)
# Requirement already satisfied: joblib>=1.2.0 in /home/meet/.local/lib/python3.10/site-packages (from scikit-learn->openfl==1.9.0.dev0) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /home/meet/.local/lib/python3.10/site-packages (from scikit-learn->openfl==1.9.0.dev0) (3.6.0)
# Requirement already satisfied: packaging in /home/meet/.local/lib/python3.10/site-packages (from tensorboardX->openfl==1.9.0.dev0) (24.2)
# Requirement already satisfied: pycparser in /home/meet/miniconda3/envs/myenv_openfl/lib/python3.10/site-packages (from cffi>=1.12->cryptography->openfl==1.9.0.dev0) (2.22)
# Requirement already satisfied: mdurl~=0.1 in /home/meet/.local/lib/python3.10/site-packages (from markdown-it-py>=2.2.0->rich->openfl==1.9.0.dev0) (0.1.2)
#
# [notice] A new release of pip is available: 25.0.1 -> 25.1.1
# [notice] To update, run: pip install --upgrade pip
# Requirement already satisfied: chardet in /home/meet/miniconda3/envs/myenv_openfl/lib/python3.10/site-packages (from -r ../../../workflow_interface_requirements.txt (line 1)) (5.2.0)
# Requirement already satisfied: charset-normalizer in /home/meet/.local/lib/python3.10/site-packages (from -r ../../../workflow_interface_requirements.txt (line 2)) (3.4.1)
# Requirement already satisfied: dill==0.3.6 in /home/meet/.local/lib/python3.10/site-packages (from -r ../../../workflow_interface_requirements.txt (line 3)) (0.3.6)
# Requirement already satisfied: matplotlib>=2.0.0 in /home/meet/.local/lib/python3.10/site-packages (from -r ../../../workflow_interface_requirements.txt (line 4)) (3.10.1)
# Requirement already satisfied: metaflow==2.7.15 in /home/meet/.local/lib/python3.10/site-packages (from -r ../../../workflow_interface_requirements.txt (line 5)) (2.7.15)
# Requirement already satisfied: nbdev==2.3.37 in /home/meet/miniconda3/envs/myenv_openfl/lib/python3.10/site-packages (from -r ../../../workflow_interface_requirements.txt (line 6)) (2.3.37)
# Requirement already satisfied: nbformat==5.10.4 in /home/meet/.local/lib/python3.10/site-packages (from -r ../../../workflow_interface_requirements.txt (line 7)) (5.10.4)
# Requirement already satisfied: ray==2.43.0 in /home/meet/miniconda3/envs/myenv_openfl/lib/python3.10/site-packages (from -r ../../../workflow_interface_requirements.txt (line 8)) (2.43.0)
# Requirement already satisfied: tabulate==0.9.0 in /home/meet/.local/lib/python3.10/site-packages (from -r ../../../workflow_interface_requirements.txt (line 9)) (0.9.0)
# Requirement already satisfied: torch==2.3.1 in /home/meet/.local/lib/python3.10/site-packages (from -r ../../../workflow_interface_requirements.txt (line 10)) (2.3.1)
# Requirement already satisfied: torchvision==0.18.1 in /home/meet/.local/lib/python3.10/site-packages (from -r ../../../workflow_interface_requirements.txt (line 11)) (0.18.1)
# Requirement already satisfied: requests in /home/meet/.local/lib/python3.10/site-packages (from metaflow==2.7.15->-r ../../../workflow_interface_requirements.txt (line 5)) (2.32.3)
# Requirement already satisfied: boto3 in /home/meet/.local/lib/python3.10/site-packages (from metaflow==2.7.15->-r ../../../workflow_interface_requirements.txt (line 5)) (1.37.13)
# Requirement already satisfied: pylint in /home/meet/.local/lib/python3.10/site-packages (from metaflow==2.7.15->-r ../../../workflow_interface_requirements.txt (line 5)) (3.3.5)
# Requirement already satisfied: packaging in /home/meet/.local/lib/python3.10/site-packages (from nbdev==2.3.37->-r ../../../workflow_interface_requirements.txt (line 6)) (24.2)
# Requirement already satisfied: fastcore>=1.8.0 in /home/meet/miniconda3/envs/myenv_openfl/lib/python3.10/site-packages (from nbdev==2.3.37->-r ../../../workflow_interface_requirements.txt (line 6)) (1.8.2)
# Requirement already satisfied: execnb>=0.1.12 in /home/meet/.local/lib/python3.10/site-packages (from nbdev==2.3.37->-r ../../../workflow_interface_requirements.txt (line 6)) (0.1.12)
# Requirement already satisfied: astunparse in /home/meet/.local/lib/python3.10/site-packages (from nbdev==2.3.37->-r ../../../workflow_interface_requirements.txt (line 6)) (1.6.3)
# Requirement already satisfied: ghapi>=1.0.3 in /home/meet/.local/lib/python3.10/site-packages (from nbdev==2.3.37->-r ../../../workflow_interface_requirements.txt (line 6)) (1.0.6)
# Requirement already satisfied: watchdog in /home/meet/.local/lib/python3.10/site-packages (from nbdev==2.3.37->-r ../../../workflow_interface_requirements.txt (line 6)) (6.0.0)
# Requirement already satisfied: asttokens in /home/meet/.local/lib/python3.10/site-packages (from nbdev==2.3.37->-r ../../../workflow_interface_requirements.txt (line 6)) (3.0.0)
# Requirement already satisfied: setuptools in /home/meet/miniconda3/envs/myenv_openfl/lib/python3.10/site-packages (from nbdev==2.3.37->-r ../../../workflow_interface_requirements.txt (line 6)) (78.1.1)
# Requirement already satisfied: plum-dispatch in /home/meet/miniconda3/envs/myenv_openfl/lib/python3.10/site-packages (from nbdev==2.3.37->-r ../../../workflow_interface_requirements.txt (line 6)) (2.5.7)
# Requirement already satisfied: PyYAML in /home/meet/miniconda3/envs/myenv_openfl/lib/python3.10/site-packages (from nbdev==2.3.37->-r ../../../workflow_interface_requirements.txt (line 6)) (6.0.2)
# Requirement already satisfied: fastjsonschema>=2.15 in /home/meet/.local/lib/python3.10/site-packages (from nbformat==5.10.4->-r ../../../workflow_interface_requirements.txt (line 7)) (2.21.1)
# Requirement already satisfied: jsonschema>=2.6 in /home/meet/.local/lib/python3.10/site-packages (from nbformat==5.10.4->-r ../../../workflow_interface_requirements.txt (line 7)) (4.23.0)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in /home/meet/.local/lib/python3.10/site-packages (from nbformat==5.10.4->-r ../../../workflow_interface_requirements.txt (line 7)) (5.7.2)
# Requirement already satisfied: traitlets>=5.1 in /home/meet/.local/lib/python3.10/site-packages (from nbformat==5.10.4->-r ../../../workflow_interface_requirements.txt (line 7)) (5.14.3)
# Requirement already satisfied: click>=7.0 in /home/meet/miniconda3/envs/myenv_openfl/lib/python3.10/site-packages (from ray==2.43.0->-r ../../../workflow_interface_requirements.txt (line 8)) (8.2.0)
# Requirement already satisfied: filelock in /home/meet/.local/lib/python3.10/site-packages (from ray==2.43.0->-r ../../../workflow_interface_requirements.txt (line 8)) (3.18.0)
# Requirement already satisfied: msgpack<2.0.0,>=1.0.0 in /home/meet/.local/lib/python3.10/site-packages (from ray==2.43.0->-r ../../../workflow_interface_requirements.txt (line 8)) (1.1.0)
# Requirement already satisfied: protobuf!=3.19.5,>=3.15.3 in /home/meet/.local/lib/python3.10/site-packages (from ray==2.43.0->-r ../../../workflow_interface_requirements.txt (line 8)) (5.29.4)
# Requirement already satisfied: aiosignal in /home/meet/.local/lib/python3.10/site-packages (from ray==2.43.0->-r ../../../workflow_interface_requirements.txt (line 8)) (1.3.2)
# Requirement already satisfied: frozenlist in /home/meet/.local/lib/python3.10/site-packages (from ray==2.43.0->-r ../../../workflow_interface_requirements.txt (line 8)) (1.5.0)
# Requirement already satisfied: typing-extensions>=4.8.0 in /home/meet/.local/lib/python3.10/site-packages (from torch==2.3.1->-r ../../../workflow_interface_requirements.txt (line 10)) (4.13.2)
# Requirement already satisfied: sympy in /home/meet/.local/lib/python3.10/site-packages (from torch==2.3.1->-r ../../../workflow_interface_requirements.txt (line 10)) (1.13.3)
# Requirement already satisfied: networkx in /home/meet/.local/lib/python3.10/site-packages (from torch==2.3.1->-r ../../../workflow_interface_requirements.txt (line 10)) (3.4.2)
# Requirement already satisfied: jinja2 in /home/meet/.local/lib/python3.10/site-packages (from torch==2.3.1->-r ../../../workflow_interface_requirements.txt (line 10)) (3.1.6)
# Requirement already satisfied: fsspec in /home/meet/.local/lib/python3.10/site-packages (from torch==2.3.1->-r ../../../workflow_interface_requirements.txt (line 10)) (2025.3.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in /home/meet/.local/lib/python3.10/site-packages (from torch==2.3.1->-r ../../../workflow_interface_requirements.txt (line 10)) (12.1.105)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in /home/meet/.local/lib/python3.10/site-packages (from torch==2.3.1->-r ../../../workflow_interface_requirements.txt (line 10)) (12.1.105)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in /home/meet/.local/lib/python3.10/site-packages (from torch==2.3.1->-r ../../../workflow_interface_requirements.txt (line 10)) (12.1.105)
# Requirement already satisfied: nvidia-cudnn-cu12==8.9.2.26 in /home/meet/.local/lib/python3.10/site-packages (from torch==2.3.1->-r ../../../workflow_interface_requirements.txt (line 10)) (8.9.2.26)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in /home/meet/.local/lib/python3.10/site-packages (from torch==2.3.1->-r ../../../workflow_interface_requirements.txt (line 10)) (12.1.3.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in /home/meet/.local/lib/python3.10/site-packages (from torch==2.3.1->-r ../../../workflow_interface_requirements.txt (line 10)) (11.0.2.54)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in /home/meet/.local/lib/python3.10/site-packages (from torch==2.3.1->-r ../../../workflow_interface_requirements.txt (line 10)) (10.3.2.106)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in /home/meet/.local/lib/python3.10/site-packages (from torch==2.3.1->-r ../../../workflow_interface_requirements.txt (line 10)) (11.4.5.107)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in /home/meet/.local/lib/python3.10/site-packages (from torch==2.3.1->-r ../../../workflow_interface_requirements.txt (line 10)) (12.1.0.106)
# Requirement already satisfied: nvidia-nccl-cu12==2.20.5 in /home/meet/.local/lib/python3.10/site-packages (from torch==2.3.1->-r ../../../workflow_interface_requirements.txt (line 10)) (2.20.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in /home/meet/.local/lib/python3.10/site-packages (from torch==2.3.1->-r ../../../workflow_interface_requirements.txt (line 10)) (12.1.105)
# Requirement already satisfied: triton==2.3.1 in /home/meet/.local/lib/python3.10/site-packages (from torch==2.3.1->-r ../../../workflow_interface_requirements.txt (line 10)) (2.3.1)
# Requirement already satisfied: numpy in /home/meet/.local/lib/python3.10/site-packages (from torchvision==0.18.1->-r ../../../workflow_interface_requirements.txt (line 11)) (2.2.4)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /home/meet/.local/lib/python3.10/site-packages (from torchvision==0.18.1->-r ../../../workflow_interface_requirements.txt (line 11)) (10.0.1)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /home/meet/.local/lib/python3.10/site-packages (from nvidia-cusolver-cu12==11.4.5.107->torch==2.3.1->-r ../../../workflow_interface_requirements.txt (line 10)) (12.8.93)
# Requirement already satisfied: contourpy>=1.0.1 in /home/meet/.local/lib/python3.10/site-packages (from matplotlib>=2.0.0->-r ../../../workflow_interface_requirements.txt (line 4)) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /home/meet/.local/lib/python3.10/site-packages (from matplotlib>=2.0.0->-r ../../../workflow_interface_requirements.txt (line 4)) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /home/meet/.local/lib/python3.10/site-packages (from matplotlib>=2.0.0->-r ../../../workflow_interface_requirements.txt (line 4)) (4.56.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /home/meet/.local/lib/python3.10/site-packages (from matplotlib>=2.0.0->-r ../../../workflow_interface_requirements.txt (line 4)) (1.4.8)
# Requirement already satisfied: pyparsing>=2.3.1 in /home/meet/miniconda3/envs/myenv_openfl/lib/python3.10/site-packages (from matplotlib>=2.0.0->-r ../../../workflow_interface_requirements.txt (line 4)) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /home/meet/.local/lib/python3.10/site-packages (from matplotlib>=2.0.0->-r ../../../workflow_interface_requirements.txt (line 4)) (2.9.0.post0)
# Requirement already satisfied: ipython in /home/meet/.local/lib/python3.10/site-packages (from execnb>=0.1.12->nbdev==2.3.37->-r ../../../workflow_interface_requirements.txt (line 6)) (8.34.0)
# Requirement already satisfied: attrs>=22.2.0 in /home/meet/.local/lib/python3.10/site-packages (from jsonschema>=2.6->nbformat==5.10.4->-r ../../../workflow_interface_requirements.txt (line 7)) (25.1.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /home/meet/.local/lib/python3.10/site-packages (from jsonschema>=2.6->nbformat==5.10.4->-r ../../../workflow_interface_requirements.txt (line 7)) (2024.10.1)
# Requirement already satisfied: referencing>=0.28.4 in /home/meet/.local/lib/python3.10/site-packages (from jsonschema>=2.6->nbformat==5.10.4->-r ../../../workflow_interface_requirements.txt (line 7)) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in /home/meet/.local/lib/python3.10/site-packages (from jsonschema>=2.6->nbformat==5.10.4->-r ../../../workflow_interface_requirements.txt (line 7)) (0.23.1)
# Requirement already satisfied: platformdirs>=2.5 in /home/meet/.local/lib/python3.10/site-packages (from jupyter-core!=5.0.*,>=4.12->nbformat==5.10.4->-r ../../../workflow_interface_requirements.txt (line 7)) (4.3.6)
# Requirement already satisfied: six>=1.5 in /home/meet/miniconda3/envs/myenv_openfl/lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib>=2.0.0->-r ../../../workflow_interface_requirements.txt (line 4)) (1.17.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /home/meet/.local/lib/python3.10/site-packages (from astunparse->nbdev==2.3.37->-r ../../../workflow_interface_requirements.txt (line 6)) (0.45.1)
# Requirement already satisfied: botocore<1.38.0,>=1.37.13 in /home/meet/.local/lib/python3.10/site-packages (from boto3->metaflow==2.7.15->-r ../../../workflow_interface_requirements.txt (line 5)) (1.37.13)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in /home/meet/.local/lib/python3.10/site-packages (from boto3->metaflow==2.7.15->-r ../../../workflow_interface_requirements.txt (line 5)) (1.0.1)
# Requirement already satisfied: s3transfer<0.12.0,>=0.11.0 in /home/meet/.local/lib/python3.10/site-packages (from boto3->metaflow==2.7.15->-r ../../../workflow_interface_requirements.txt (line 5)) (0.11.4)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/meet/.local/lib/python3.10/site-packages (from jinja2->torch==2.3.1->-r ../../../workflow_interface_requirements.txt (line 10)) (3.0.2)
# Requirement already satisfied: beartype>=0.16.2 in /home/meet/.local/lib/python3.10/site-packages (from plum-dispatch->nbdev==2.3.37->-r ../../../workflow_interface_requirements.txt (line 6)) (0.20.0)
# Requirement already satisfied: rich>=10.0 in /home/meet/.local/lib/python3.10/site-packages (from plum-dispatch->nbdev==2.3.37->-r ../../../workflow_interface_requirements.txt (line 6)) (14.0.0)
# Requirement already satisfied: astroid<=3.4.0-dev0,>=3.3.8 in /home/meet/.local/lib/python3.10/site-packages (from pylint->metaflow==2.7.15->-r ../../../workflow_interface_requirements.txt (line 5)) (3.3.9)
# Requirement already satisfied: isort!=5.13.0,<7,>=4.2.5 in /home/meet/.local/lib/python3.10/site-packages (from pylint->metaflow==2.7.15->-r ../../../workflow_interface_requirements.txt (line 5)) (6.0.1)
# Requirement already satisfied: mccabe<0.8,>=0.6 in /home/meet/.local/lib/python3.10/site-packages (from pylint->metaflow==2.7.15->-r ../../../workflow_interface_requirements.txt (line 5)) (0.7.0)
# Requirement already satisfied: tomli>=1.1.0 in /home/meet/.local/lib/python3.10/site-packages (from pylint->metaflow==2.7.15->-r ../../../workflow_interface_requirements.txt (line 5)) (2.2.1)
# Requirement already satisfied: tomlkit>=0.10.1 in /home/meet/.local/lib/python3.10/site-packages (from pylint->metaflow==2.7.15->-r ../../../workflow_interface_requirements.txt (line 5)) (0.13.2)
# Requirement already satisfied: idna<4,>=2.5 in /home/meet/miniconda3/envs/myenv_openfl/lib/python3.10/site-packages (from requests->metaflow==2.7.15->-r ../../../workflow_interface_requirements.txt (line 5)) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/meet/miniconda3/envs/myenv_openfl/lib/python3.10/site-packages (from requests->metaflow==2.7.15->-r ../../../workflow_interface_requirements.txt (line 5)) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /home/meet/miniconda3/envs/myenv_openfl/lib/python3.10/site-packages (from requests->metaflow==2.7.15->-r ../../../workflow_interface_requirements.txt (line 5)) (2025.4.26)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /home/meet/.local/lib/python3.10/site-packages (from sympy->torch==2.3.1->-r ../../../workflow_interface_requirements.txt (line 10)) (1.3.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /home/meet/.local/lib/python3.10/site-packages (from rich>=10.0->plum-dispatch->nbdev==2.3.37->-r ../../../workflow_interface_requirements.txt (line 6)) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /home/meet/.local/lib/python3.10/site-packages (from rich>=10.0->plum-dispatch->nbdev==2.3.37->-r ../../../workflow_interface_requirements.txt (line 6)) (2.19.1)
# Requirement already satisfied: decorator in /home/meet/.local/lib/python3.10/site-packages (from ipython->execnb>=0.1.12->nbdev==2.3.37->-r ../../../workflow_interface_requirements.txt (line 6)) (5.2.1)
# Requirement already satisfied: exceptiongroup in /home/meet/.local/lib/python3.10/site-packages (from ipython->execnb>=0.1.12->nbdev==2.3.37->-r ../../../workflow_interface_requirements.txt (line 6)) (1.2.2)
# Requirement already satisfied: jedi>=0.16 in /home/meet/.local/lib/python3.10/site-packages (from ipython->execnb>=0.1.12->nbdev==2.3.37->-r ../../../workflow_interface_requirements.txt (line 6)) (0.19.2)
# Requirement already satisfied: matplotlib-inline in /home/meet/.local/lib/python3.10/site-packages (from ipython->execnb>=0.1.12->nbdev==2.3.37->-r ../../../workflow_interface_requirements.txt (line 6)) (0.1.7)
# Requirement already satisfied: pexpect>4.3 in /home/meet/.local/lib/python3.10/site-packages (from ipython->execnb>=0.1.12->nbdev==2.3.37->-r ../../../workflow_interface_requirements.txt (line 6)) (4.9.0)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in /home/meet/.local/lib/python3.10/site-packages (from ipython->execnb>=0.1.12->nbdev==2.3.37->-r ../../../workflow_interface_requirements.txt (line 6)) (3.0.50)
# Requirement already satisfied: stack_data in /home/meet/.local/lib/python3.10/site-packages (from ipython->execnb>=0.1.12->nbdev==2.3.37->-r ../../../workflow_interface_requirements.txt (line 6)) (0.6.3)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /home/meet/.local/lib/python3.10/site-packages (from jedi>=0.16->ipython->execnb>=0.1.12->nbdev==2.3.37->-r ../../../workflow_interface_requirements.txt (line 6)) (0.8.4)
# Requirement already satisfied: mdurl~=0.1 in /home/meet/.local/lib/python3.10/site-packages (from markdown-it-py>=2.2.0->rich>=10.0->plum-dispatch->nbdev==2.3.37->-r ../../../workflow_interface_requirements.txt (line 6)) (0.1.2)
# Requirement already satisfied: ptyprocess>=0.5 in /home/meet/.local/lib/python3.10/site-packages (from pexpect>4.3->ipython->execnb>=0.1.12->nbdev==2.3.37->-r ../../../workflow_interface_requirements.txt (line 6)) (0.7.0)
# Requirement already satisfied: wcwidth in /home/meet/.local/lib/python3.10/site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython->execnb>=0.1.12->nbdev==2.3.37->-r ../../../workflow_interface_requirements.txt (line 6)) (0.2.13)
# Requirement already satisfied: executing>=1.2.0 in /home/meet/.local/lib/python3.10/site-packages (from stack_data->ipython->execnb>=0.1.12->nbdev==2.3.37->-r ../../../workflow_interface_requirements.txt (line 6)) (2.2.0)
# Requirement already satisfied: pure-eval in /home/meet/.local/lib/python3.10/site-packages (from stack_data->ipython->execnb>=0.1.12->nbdev==2.3.37->-r ../../../workflow_interface_requirements.txt (line 6)) (0.2.3)
#
# [notice] A new release of pip is available: 25.0.1 -> 25.1.1
# [notice] To update, run: pip install --upgrade pip
# Requirement already satisfied: torch==2.3.1 in /home/meet/.local/lib/python3.10/site-packages (2.3.1)
# Requirement already satisfied: filelock in /home/meet/.local/lib/python3.10/site-packages (from torch==2.3.1) (3.18.0)
# Requirement already satisfied: typing-extensions>=4.8.0 in /home/meet/.local/lib/python3.10/site-packages (from torch==2.3.1) (4.13.2)
# Requirement already satisfied: sympy in /home/meet/.local/lib/python3.10/site-packages (from torch==2.3.1) (1.13.3)
# Requirement already satisfied: networkx in /home/meet/.local/lib/python3.10/site-packages (from torch==2.3.1) (3.4.2)
# Requirement already satisfied: jinja2 in /home/meet/.local/lib/python3.10/site-packages (from torch==2.3.1) (3.1.6)
# Requirement already satisfied: fsspec in /home/meet/.local/lib/python3.10/site-packages (from torch==2.3.1) (2025.3.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in /home/meet/.local/lib/python3.10/site-packages (from torch==2.3.1) (12.1.105)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in /home/meet/.local/lib/python3.10/site-packages (from torch==2.3.1) (12.1.105)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in /home/meet/.local/lib/python3.10/site-packages (from torch==2.3.1) (12.1.105)
# Requirement already satisfied: nvidia-cudnn-cu12==8.9.2.26 in /home/meet/.local/lib/python3.10/site-packages (from torch==2.3.1) (8.9.2.26)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in /home/meet/.local/lib/python3.10/site-packages (from torch==2.3.1) (12.1.3.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in /home/meet/.local/lib/python3.10/site-packages (from torch==2.3.1) (11.0.2.54)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in /home/meet/.local/lib/python3.10/site-packages (from torch==2.3.1) (10.3.2.106)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in /home/meet/.local/lib/python3.10/site-packages (from torch==2.3.1) (11.4.5.107)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in /home/meet/.local/lib/python3.10/site-packages (from torch==2.3.1) (12.1.0.106)
# Requirement already satisfied: nvidia-nccl-cu12==2.20.5 in /home/meet/.local/lib/python3.10/site-packages (from torch==2.3.1) (2.20.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in /home/meet/.local/lib/python3.10/site-packages (from torch==2.3.1) (12.1.105)
# Requirement already satisfied: triton==2.3.1 in /home/meet/.local/lib/python3.10/site-packages (from torch==2.3.1) (2.3.1)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /home/meet/.local/lib/python3.10/site-packages (from nvidia-cusolver-cu12==11.4.5.107->torch==2.3.1) (12.8.93)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/meet/.local/lib/python3.10/site-packages (from jinja2->torch==2.3.1) (3.0.2)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /home/meet/.local/lib/python3.10/site-packages (from sympy->torch==2.3.1) (1.3.0)
#
# [notice] A new release of pip is available: 25.0.1 -> 25.1.1
# [notice] To update, run: pip install --upgrade pip
# Requirement already satisfied: torchvision==0.18.1 in /home/meet/.local/lib/python3.10/site-packages (0.18.1)
# Requirement already satisfied: numpy in /home/meet/.local/lib/python3.10/site-packages (from torchvision==0.18.1) (2.2.4)
# Requirement already satisfied: torch==2.3.1 in /home/meet/.local/lib/python3.10/site-packages (from torchvision==0.18.1) (2.3.1)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /home/meet/.local/lib/python3.10/site-packages (from torchvision==0.18.1) (10.0.1)
# Requirement already satisfied: filelock in /home/meet/.local/lib/python3.10/site-packages (from torch==2.3.1->torchvision==0.18.1) (3.18.0)
# Requirement already satisfied: typing-extensions>=4.8.0 in /home/meet/.local/lib/python3.10/site-packages (from torch==2.3.1->torchvision==0.18.1) (4.13.2)
# Requirement already satisfied: sympy in /home/meet/.local/lib/python3.10/site-packages (from torch==2.3.1->torchvision==0.18.1) (1.13.3)
# Requirement already satisfied: networkx in /home/meet/.local/lib/python3.10/site-packages (from torch==2.3.1->torchvision==0.18.1) (3.4.2)
# Requirement already satisfied: jinja2 in /home/meet/.local/lib/python3.10/site-packages (from torch==2.3.1->torchvision==0.18.1) (3.1.6)
# Requirement already satisfied: fsspec in /home/meet/.local/lib/python3.10/site-packages (from torch==2.3.1->torchvision==0.18.1) (2025.3.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in /home/meet/.local/lib/python3.10/site-packages (from torch==2.3.1->torchvision==0.18.1) (12.1.105)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in /home/meet/.local/lib/python3.10/site-packages (from torch==2.3.1->torchvision==0.18.1) (12.1.105)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in /home/meet/.local/lib/python3.10/site-packages (from torch==2.3.1->torchvision==0.18.1) (12.1.105)
# Requirement already satisfied: nvidia-cudnn-cu12==8.9.2.26 in /home/meet/.local/lib/python3.10/site-packages (from torch==2.3.1->torchvision==0.18.1) (8.9.2.26)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in /home/meet/.local/lib/python3.10/site-packages (from torch==2.3.1->torchvision==0.18.1) (12.1.3.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in /home/meet/.local/lib/python3.10/site-packages (from torch==2.3.1->torchvision==0.18.1) (11.0.2.54)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in /home/meet/.local/lib/python3.10/site-packages (from torch==2.3.1->torchvision==0.18.1) (10.3.2.106)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in /home/meet/.local/lib/python3.10/site-packages (from torch==2.3.1->torchvision==0.18.1) (11.4.5.107)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in /home/meet/.local/lib/python3.10/site-packages (from torch==2.3.1->torchvision==0.18.1) (12.1.0.106)
# Requirement already satisfied: nvidia-nccl-cu12==2.20.5 in /home/meet/.local/lib/python3.10/site-packages (from torch==2.3.1->torchvision==0.18.1) (2.20.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in /home/meet/.local/lib/python3.10/site-packages (from torch==2.3.1->torchvision==0.18.1) (12.1.105)
# Requirement already satisfied: triton==2.3.1 in /home/meet/.local/lib/python3.10/site-packages (from torch==2.3.1->torchvision==0.18.1) (2.3.1)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /home/meet/.local/lib/python3.10/site-packages (from nvidia-cusolver-cu12==11.4.5.107->torch==2.3.1->torchvision==0.18.1) (12.8.93)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/meet/.local/lib/python3.10/site-packages (from jinja2->torch==2.3.1->torchvision==0.18.1) (3.0.2)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /home/meet/.local/lib/python3.10/site-packages (from sympy->torch==2.3.1->torchvision==0.18.1) (1.3.0)
#
# [notice] A new release of pip is available: 25.0.1 -> 25.1.1
# [notice] To update, run: pip install --upgrade pip
# Requirement already satisfied: ipywidgets in /home/meet/miniconda3/envs/myenv_openfl/lib/python3.10/site-packages (8.1.7)
# Requirement already satisfied: comm>=0.1.3 in /home/meet/.local/lib/python3.10/site-packages (from ipywidgets) (0.2.2)
# Requirement already satisfied: ipython>=6.1.0 in /home/meet/.local/lib/python3.10/site-packages (from ipywidgets) (8.34.0)
# Requirement already satisfied: traitlets>=4.3.1 in /home/meet/.local/lib/python3.10/site-packages (from ipywidgets) (5.14.3)
# Requirement already satisfied: widgetsnbextension~=4.0.14 in /home/meet/miniconda3/envs/myenv_openfl/lib/python3.10/site-packages (from ipywidgets) (4.0.14)
# Requirement already satisfied: jupyterlab_widgets~=3.0.15 in /home/meet/miniconda3/envs/myenv_openfl/lib/python3.10/site-packages (from ipywidgets) (3.0.15)
# Requirement already satisfied: decorator in /home/meet/.local/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets) (5.2.1)
# Requirement already satisfied: exceptiongroup in /home/meet/.local/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets) (1.2.2)
# Requirement already satisfied: jedi>=0.16 in /home/meet/.local/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets) (0.19.2)
# Requirement already satisfied: matplotlib-inline in /home/meet/.local/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets) (0.1.7)
# Requirement already satisfied: pexpect>4.3 in /home/meet/.local/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets) (4.9.0)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in /home/meet/.local/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets) (3.0.50)
# Requirement already satisfied: pygments>=2.4.0 in /home/meet/.local/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets) (2.19.1)
# Requirement already satisfied: stack_data in /home/meet/.local/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets) (0.6.3)
# Requirement already satisfied: typing_extensions>=4.6 in /home/meet/.local/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets) (4.13.2)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /home/meet/.local/lib/python3.10/site-packages (from jedi>=0.16->ipython>=6.1.0->ipywidgets) (0.8.4)
# Requirement already satisfied: ptyprocess>=0.5 in /home/meet/.local/lib/python3.10/site-packages (from pexpect>4.3->ipython>=6.1.0->ipywidgets) (0.7.0)
# Requirement already satisfied: wcwidth in /home/meet/.local/lib/python3.10/site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython>=6.1.0->ipywidgets) (0.2.13)
# Requirement already satisfied: executing>=1.2.0 in /home/meet/.local/lib/python3.10/site-packages (from stack_data->ipython>=6.1.0->ipywidgets) (2.2.0)
# Requirement already satisfied: asttokens>=2.1.0 in /home/meet/.local/lib/python3.10/site-packages (from stack_data->ipython>=6.1.0->ipywidgets) (3.0.0)
# Requirement already satisfied: pure-eval in /home/meet/.local/lib/python3.10/site-packages (from stack_data->ipython>=6.1.0->ipywidgets) (0.2.3)
#
# [notice] A new release of pip is available: 25.0.1 -> 25.1.1
# [notice] To update, run: pip install --upgrade pip

# %% [markdown]
# ### Model definition

# %% [markdown]
# We begin with the quintessential example of a pytorch CNN model trained on the MNIST dataset. Let's start by defining
# - Hyperparameters
# - Model definition, and
# - Helper functions to train and validate the model like we would for any other deep learning experiment

# %%
# | export

import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import torch
import numpy as np
import random

# Hyperparameters
learning_rate = 0.01
momentum = 0.5
batch_size = 32
log_interval = 10

# Model definition
class Net(nn.Module):
    def __init__(self):
        super(Net, self).__init__()
        self.conv1 = nn.Conv2d(1, 10, kernel_size=5)
        self.conv2 = nn.Conv2d(10, 20, kernel_size=5)
        self.fc1 = nn.Linear(320, 50)
        self.fc2 = nn.Linear(50, 10)

    def forward(self, x):
        x = F.relu(F.max_pool2d(self.conv1(x), 2))
        x = F.relu(F.max_pool2d(self.conv2(x), 2))
        x = x.view(-1, 320)
        x = F.relu(self.fc1(x))
        x = self.fc2(x)
        return F.log_softmax(x)


# Helper function to validate the model
def validate(model, test_loader):
    model.eval()
    correct = 0
    with torch.no_grad():
        for data, target in test_loader:
            output = model(data)
            pred = output.data.max(1, keepdim=True)[1]
            correct += pred.eq(target.data.view_as(pred)).sum()
    accuracy = float(correct / len(test_loader.dataset))
    return accuracy


# Helper function to train the model
def train_model(model, optimizer, data_loader, round_number, log=False):
    train_loss = 0
    model.train()
    for batch_idx, (X, y) in enumerate(data_loader):
        optimizer.zero_grad()

        output = model(X)
        loss = F.nll_loss(output, y)
        loss.backward()

        optimizer.step()

        train_loss += loss.item() * len(X)
        if batch_idx % log_interval == 0 and log:
            print(
                "Train Epoch: {:3} [{:5}/{:<5} ({:<.0f}%)] Loss: {:<.4f}".format(
                    round_number,
                    batch_idx * len(X),
                    len(data_loader.dataset),
                    100.0 * batch_idx / len(data_loader),
                    loss.item(),
                )
            )

    train_loss /= len(data_loader.dataset)
    return train_loss


# Helper function to initialize seed for reproducibility
def initialize_seed(random_seed=42):
    torch.manual_seed(random_seed)
    np.random.seed(random_seed)
    random.seed(random_seed)

# %% [markdown]
# ### Dataset definition
#
# We now download the training and test datasets of MNIST, a necessary step to demonstrate the functionality of the LocalRuntime.

# %%
#| export

import torchvision

# Train and Test datasets
mnist_train = torchvision.datasets.MNIST(
    "../files/",
    train=True,
    download=True,
    transform=torchvision.transforms.Compose(
        [
            torchvision.transforms.ToTensor(),
            torchvision.transforms.Normalize((0.1307,), (0.3081,)),
        ]
    ),
)

mnist_test = torchvision.datasets.MNIST(
    "../files/",
    train=False,
    download=True,
    transform=torchvision.transforms.Compose(
        [
            torchvision.transforms.ToTensor(),
            torchvision.transforms.Normalize((0.1307,), (0.3081,)),
        ]
    ),
)

# %% [markdown]
# ### Workflow definition

# %% [markdown]
# Next we import the `FLSpec`, placement decorators (`aggregator/collaborator`), and define the `FedAvg` helper function
#
# - `FLSpec` – Defines the flow specification. User defined flows are subclasses of this.
# - `aggregator/collaborator` - placement decorators that define where the task will be assigned
# - `FedAvg` - helper function for Federated Averaging

# %%
# | export

from copy import deepcopy

from openfl.experimental.workflow.interface import FLSpec
from openfl.experimental.workflow.placement import aggregator, collaborator


# Helper function for federated averaging
def FedAvg(agg_model, models, weights=None):
    state_dicts = [model.state_dict() for model in models]
    agg_state_dict = agg_model.state_dict()
    for key in models[0].state_dict():
        agg_state_dict[key] = torch.from_numpy(
            np.average([state[key].numpy() for state in state_dicts], axis=0, weights=weights)
        )

    agg_model.load_state_dict(agg_state_dict)
    return agg_model

# %% [markdown]
# Let us now define the Workflow. Here we use the same tasks as the [101 MNIST](https://github.com/securefederatedai/openfl/blob/develop/openfl-tutorials/experimental/workflow/101_MNIST.ipynb)

# %%
# | export

class FederatedFlow_TorchMNIST(FLSpec):
    """
    This Flow trains a CNN on MNIST Model in Federated Learning
    """

    def __init__(self, model=None, optimizer=None, learning_rate=1e-2, momentum=0.5, rounds=3, **kwargs):
        super().__init__(**kwargs)

        if model is not None:
            self.model = model
            self.optimizer = optimizer
        else:
            initialize_seed()
            self.model = Net()
            self.optimizer = optim.SGD(self.model.parameters(), lr=learning_rate, momentum=momentum)

        self.learning_rate = learning_rate
        self.momentum = momentum
        self.rounds = rounds
        self.results = []

    @aggregator
    def start(self):
        """
        This is the start of the Flow.
        """
        print(f"Initializing Workflow .... ")

        self.collaborators = self.runtime.collaborators
        self.current_round = 0

        self.next(self.aggregated_model_validation, foreach="collaborators")

    @collaborator
    def aggregated_model_validation(self):
        """
        Perform validation of aggregated model on collaborators.
        """
        print(f"<Collab: {self.input}> Performing Validation on aggregated model ... ")
        self.agg_validation_score = validate(self.model, self.test_loader)
        print(
            f"<Collab: {self.input}> Aggregated Model validation score = {self.agg_validation_score:.4f}"
        )

        self.next(self.train)

    @collaborator
    def train(self):
        """
        Train model on Local collaborator dataset.
        """
        print(f"<Collab: {self.input}>: Training Model on local dataset ... ")

        self.optimizer = optim.SGD(self.model.parameters(), lr=self.learning_rate, momentum=self.momentum)

        self.loss = train_model(
            model=self.model,
            optimizer=self.optimizer,
            data_loader=self.train_loader,
            round_number=self.current_round,
            log=True,
        )

        self.next(self.local_model_validation)

    @collaborator
    def local_model_validation(self):
        """
        Validate locally trained model.
        """
        print(f"<Collab: {self.input}> Performing Validation on locally trained model ... ")
        self.local_validation_score = validate(self.model, self.test_loader)
        print(
            f"<Collab: {self.input}> Local model validation score = {self.local_validation_score:.4f}"
        )
        self.next(self.join)

    @aggregator
    def join(self, inputs):
        """
        Model aggregation step.
        """
        print(f"<Agg>: Joining models from collaborators...")

        # Average Training loss, aggregated and locally trained model accuracy
        self.average_loss = sum(input.loss for input in inputs) / len(inputs)
        self.aggregated_model_accuracy = sum(input.agg_validation_score for input in inputs) / len(inputs)
        self.local_model_accuracy = sum(input.local_validation_score for input in inputs) / len(inputs)

        print(f"Avg. aggregated model validation score = {self.aggregated_model_accuracy:.4f}")
        print(f"Avg. training loss = {self.average_loss:.4f}")
        print(f"Avg. local model validation score = {self.local_model_accuracy:.4f}")

        # FedAvg
        self.model = FedAvg(self.model, [input.model for input in inputs])

        self.results.append(
            [
                self.current_round,
                self.aggregated_model_accuracy,
                self.average_loss,
                self.local_model_accuracy,
            ]
        )

        self.current_round += 1
        if self.current_round < self.rounds:
            self.next( self.aggregated_model_validation, foreach="collaborators")
        else:
            self.next(self.end)

    @aggregator
    def end(self):
        """
        This is the last step in the Flow.
        """
        print(f"This is the end of the flow")
# Out:
# Aggregator step "start" registered
# Collaborator step "aggregated_model_validation" registered
# Collaborator step "train" registered
# Collaborator step "local_model_validation" registered
# Aggregator step "join" registered
# Aggregator step "end" registered

# %% [markdown]
# ### Simulation: LocalRuntime

# %% [markdown]
# We now import & define the `LocalRuntime`, participants (`Aggregator/Collaborator`), and initialize the private attributes for participants
#
# - `Runtime` – Defines where the flow runs. `LocalRuntime` simulates the flow on local node.
# - `Aggregator/Collaborator` - (Local) Participants in the simulation

# %%
# | export

from openfl.experimental.workflow.interface import Aggregator, Collaborator
from openfl.experimental.workflow.runtime import LocalRuntime

# Setup Aggregator & initialize private attributes
aggregator = Aggregator()
aggregator.private_attributes = {}

# Setup Collaborators & initialize shards of MNIST dataset as private attributes
n_collaborators = 2
collaborator_names = ["Portland", "Seattle"]

collaborators = [Collaborator(name=name) for name in collaborator_names]
for idx, collaborator in enumerate(collaborators):
    local_train = deepcopy(mnist_train)
    local_test = deepcopy(mnist_test)
    local_train.data = mnist_train.data[idx::n_collaborators]
    local_train.targets = mnist_train.targets[idx::n_collaborators]
    local_test.data = mnist_test.data[idx::n_collaborators]
    local_test.targets = mnist_test.targets[idx::n_collaborators]

    collaborator.private_attributes = {
        "train_loader": torch.utils.data.DataLoader(
            local_train, batch_size=batch_size, shuffle=False
        ),
        "test_loader": torch.utils.data.DataLoader(
            local_test, batch_size=batch_size, shuffle=False
        ),
    }

local_runtime = LocalRuntime(
    aggregator=aggregator, collaborators=collaborators, backend="single_process"
)
print(f"Local runtime collaborators = {local_runtime.collaborators}")
# Out:
# Local runtime collaborators = ['Portland', 'Seattle']

# %% [markdown]
# ### Start Simulation

# %% [markdown]
# Now that we have our flow and runtime defined, let's run the simulation !

# %%
#| export

model = None
optimizer = None
flflow = FederatedFlow_TorchMNIST(model, optimizer, learning_rate, momentum, rounds=2, checkpoint=True)
flflow.runtime = local_runtime
flflow.run()
# Out:
# Created flow FederatedFlow_TorchMNIST
#
# Calling start
# Initializing Workflow ....
# Saving data artifacts for start
# Saved data artifacts for start
#
# Calling aggregated_model_validation
# <Collab: Portland> Performing Validation on aggregated model ...
# /tmp/ipykernel_92732/2599649333.py:31: UserWarning: Implicit dimension choice for log_softmax has been deprecated. Change the call to include dim=X as an argument.
#   return F.log_softmax(x)
# <Collab: Portland> Aggregated Model validation score = 0.0668
# Saving data artifacts for aggregated_model_validation
# Saved data artifacts for aggregated_model_validation
#
# Calling train
# <Collab: Portland>: Training Model on local dataset ...
# Train Epoch:   0 [    0/30000 (0%)] Loss: 2.3144
# Train Epoch:   0 [  320/30000 (1%)] Loss: 2.3238
# Train Epoch:   0 [  640/30000 (2%)] Loss: 2.2650
# Train Epoch:   0 [  960/30000 (3%)] Loss: 2.2825
# Train Epoch:   0 [ 1280/30000 (4%)] Loss: 2.2410
# Train Epoch:   0 [ 1600/30000 (5%)] Loss: 2.2530
# Train Epoch:   0 [ 1920/30000 (6%)] Loss: 2.2225
# Train Epoch:   0 [ 2240/30000 (7%)] Loss: 2.2054
# Train Epoch:   0 [ 2560/30000 (9%)] Loss: 2.1118
# Train Epoch:   0 [ 2880/30000 (10%)] Loss: 2.0258
# Train Epoch:   0 [ 3200/30000 (11%)] Loss: 1.8625
# Train Epoch:   0 [ 3520/30000 (12%)] Loss: 1.5441
# Train Epoch:   0 [ 3840/30000 (13%)] Loss: 1.5020
# Train Epoch:   0 [ 4160/30000 (14%)] Loss: 1.0118
# Train Epoch:   0 [ 4480/30000 (15%)] Loss: 0.8876
# Train Epoch:   0 [ 4800/30000 (16%)] Loss: 0.6593
# Train Epoch:   0 [17920/30000 (60%)] Loss: 0.2306
# Train Epoch:   0 [18240/30000 (61%)] Loss: 0.1090
# Train Epoch:   0 [18560/30000 (62%)] Loss: 0.0884
# Train Epoch:   0 [18880/30000 (63%)] Loss: 0.0794
# Train Epoch:   0 [19200/30000 (64%)] Loss: 0.0735
# Train Epoch:   0 [19520/30000 (65%)] Loss: 0.1019
# Train Epoch:   0 [19840/30000 (66%)] Loss: 0.1248
# Train Epoch:   0 [20160/30000 (67%)] Loss: 0.0323
# Train Epoch:   0 [20480/30000 (68%)] Loss: 0.1643
# Train Epoch:   0 [20800/30000 (69%)] Loss: 0.0349
# Train Epoch:   0 [21120/30000 (70%)] Loss: 0.0384
# Train Epoch:   0 [21440/30000 (71%)] Loss: 0.4919
# Train Epoch:   0 [21760/30000 (72%)] Loss: 0.0617
# Train Epoch:   0 [22080/30000 (74%)] Loss: 0.0455
# Train Epoch:   0 [22400/30000 (75%)] Loss: 0.1251
# Train Epoch:   0 [22720/30000 (76%)] Loss: 0.1384
# Train Epoch:   0 [23040/30000 (77%)] Loss: 0.0310
# Train Epoch:   0 [23360/30000 (78%)] Loss: 0.0135
# Train Epoch:   0 [23680/30000 (79%)] Loss: 0.2635
# Train Epoch:   0 [24000/30000 (80%)] Loss: 0.1007
# Train Epoch:   0 [24320/30000 (81%)] Loss: 0.4353
# Train Epoch:   0 [24640/30000 (82%)] Loss: 0.0353
# Train Epoch:   0 [24960/30000 (83%)] Loss: 0.2826
# Train Epoch:   0 [25280/30000 (84%)] Loss: 0.2848
# Train Epoch:   0 [25600/30000 (85%)] Loss: 0.0817
# Train Epoch:   0 [25920/30000 (86%)] Loss: 0.1217
# Train Epoch:   0 [26240/30000 (87%)] Loss: 0.0188
# Train Epoch:   0 [26560/30000 (88%)] Loss: 0.1454
# Train Epoch:   0 [26880/30000 (90%)] Loss: 0.0193
# Train Epoch:   0 [27200/30000 (91%)] Loss: 0.2450
# Train Epoch:   0 [27520/30000 (92%)] Loss: 0.0054
# Train Epoch:   0 [27840/30000 (93%)] Loss: 0.3102
# Train Epoch:   0 [28160/30000 (94%)] Loss: 0.0636
# Train Epoch:   0 [28480/30000 (95%)] Loss: 0.1280
# Train Epoch:   0 [28800/30000 (96%)] Loss: 0.0740
# Train Epoch:   0 [29120/30000 (97%)] Loss: 0.0298
# Train Epoch:   0 [29440/30000 (98%)] Loss: 0.0444
# Train Epoch:   0 [29760/30000 (99%)] Loss: 0.0840
# Saving data artifacts for train
# Saved data artifacts for train
#
# Calling local_model_validation
# <Collab: Seattle> Performing Validation on locally trained model ...
# <Collab: Seattle> Local model validation score = 0.9298
# Saving data artifacts for local_model_validation
# Saved data artifacts for local_model_validation
# Should transfer from local_model_validation to join
#
# Calling join
# <Agg>: Joining models from collaborators...
# Avg. aggregated model validation score = 0.0664
# Avg. training loss = 0.4846
# Avg. local model validation score = 0.9370
# Saving data artifacts for join
# Saved data artifacts for join
#
# Calling aggregated_model_validation
# <Collab: Portland> Performing Validation on aggregated model ...
# <Collab: Portland> Aggregated Model validation score = 0.9410
# Saving data artifacts for aggregated_model_validation
# Saved data artifacts for aggregated_model_validation
#
# Calling train
# Saving data artifacts for train
# Saved data artifacts for train
#
# Calling local_model_validation
# <Collab: Portland> Performing Validation on locally trained model ...
# <Collab: Portland> Local model validation score = 0.9600
# Saving data artifacts for local_model_validation
# Saved data artifacts for local_model_validation
# Should transfer from local_model_validation to join
#
# Calling aggregated_model_validation
# <Collab: Seattle> Performing Validation on aggregated model ...
# <Collab: Seattle> Aggregated Model validation score = 0.9448
# Saving data artifacts for aggregated_model_validation
# Saved data artifacts for aggregated_model_validation
#
# Calling train
# <Collab: Seattle>: Training Model on local dataset ...
# Train Epoch:   1 [    0/30000 (0%)] Loss: 0.0656
# Train Epoch:   1 [  320/30000 (1%)] Loss: 0.0253
# Train Epoch:   1 [  640/30000 (2%)] Loss: 0.0453
# Train Epoch:   1 [  960/30000 (3%)] Loss: 0.0410
# Train Epoch:   1 [ 1280/30000 (4%)] Loss: 0.0341
# Train Epoch:   1 [ 1600/30000 (5%)] Loss: 0.0319
# Train Epoch:   1 [ 1920/30000 (6%)] Loss: 0.0519
# Train Epoch:   1 [ 2240/30000 (7%)] Loss: 0.0115
# Train Epoch:   1 [ 2560/30000 (9%)] Loss: 0.1200
# Train Epoch:   1 [ 2880/30000 (10%)] Loss: 0.2166
# Train Epoch:   1 [ 3200/30000 (11%)] Loss: 0.0386
# Train Epoch:   1 [ 3520/30000 (12%)] Loss: 0.0898
# Train Epoch:   1 [ 3840/30000 (13%)] Loss: 0.0329
# Train Epoch:   1 [ 4160/30000 (14%)] Loss: 0.1524
# Train Epoch:   1 [ 4480/30000 (15%)] Loss: 0.0450
# Train Epoch:   1 [ 4800/30000 (16%)] Loss: 0.1608
# Train Epoch:   1 [ 5120/30000 (17%)] Loss: 0.0979
# Train Epoch:   1 [ 5440/30000 (18%)] Loss: 0.0583
# Train Epoch:   1 [ 5760/30000 (19%)] Loss: 0.0244
# Train Epoch:   1 [ 6080/30000 (20%)] Loss: 0.0332
# Train Epoch:   1 [ 6400/30000 (21%)] Loss: 0.0151
# Train Epoch:   1 [ 6720/30000 (22%)] Loss: 0.0064
# Train Epoch:   1 [ 7040/30000 (23%)] Loss: 0.0156
# Train Epoch:   1 [ 7360/30000 (25%)] Loss: 0.3496
# Train Epoch:   1 [ 7680/30000 (26%)] Loss: 0.0669
# Train Epoch:   1 [ 8000/30000 (27%)] Loss: 0.2734
# Train Epoch:   1 [ 8320/30000 (28%)] Loss: 0.0079
# Train Epoch:   1 [ 8640/30000 (29%)] Loss: 0.0074
# Train Epoch:   1 [ 8960/30000 (30%)] Loss: 0.1620
# Train Epoch:   1 [ 9280/30000 (31%)] Loss: 0.0514
# Train Epoch:   1 [ 9600/30000 (32%)] Loss: 0.0250
# Train Epoch:   1 [ 9920/30000 (33%)] Loss: 0.0038
# Train Epoch:   1 [10240/30000 (34%)] Loss: 0.0049
# Train Epoch:   1 [10560/30000 (35%)] Loss: 0.0025
# Train Epoch:   1 [10880/30000 (36%)] Loss: 0.0105
# Train Epoch:   1 [11200/30000 (37%)] Loss: 0.0175
# Train Epoch:   1 [11520/30000 (38%)] Loss: 0.1913
# Train Epoch:   1 [11840/30000 (39%)] Loss: 0.0224
# Train Epoch:   1 [12160/30000 (41%)] Loss: 0.0181
# Train Epoch:   1 [27520/30000 (92%)] Loss: 0.0021
# Train Epoch:   1 [27840/30000 (93%)] Loss: 0.1682
# Train Epoch:   1 [28160/30000 (94%)] Loss: 0.0196
# Train Epoch:   1 [28480/30000 (95%)] Loss: 0.0494
# Train Epoch:   1 [28800/30000 (96%)] Loss: 0.0710
# Train Epoch:   1 [29120/30000 (97%)] Loss: 0.0056
# Train Epoch:   1 [29440/30000 (98%)] Loss: 0.0360
# Train Epoch:   1 [29760/30000 (99%)] Loss: 0.0428
# Saving data artifacts for train
# Saved data artifacts for train
#
# Calling local_model_validation
# <Collab: Seattle> Performing Validation on locally trained model ...
# <Collab: Seattle> Local model validation score = 0.9478
# Saving data artifacts for local_model_validation
# Saved data artifacts for local_model_validation
# Should transfer from local_model_validation to join
#
# Calling join
# <Agg>: Joining models from collaborators...
# Avg. aggregated model validation score = 0.9429
# Avg. training loss = 0.1238
# Avg. local model validation score = 0.9539
# Saving data artifacts for join
# Saved data artifacts for join
#
# Calling end
# This is the end of the flow
# Saving data artifacts for end
# Saved data artifacts for end

# %% [markdown]
# Let us check the simulation results

# %%
from tabulate import tabulate 

headers = ["Rounds", "Agg Model Validation Score", "Local Train loss", "Local Model Validation score"]
print('********** Simulation results **********')
simulation_results = flflow.results
print(tabulate(simulation_results, headers=headers, tablefmt="outline"))
# Out:
# ********** Simulation results **********
# +----------+------------------------------+--------------------+--------------------------------+
# |   Rounds |   Agg Model Validation Score |   Local Train loss |   Local Model Validation score |
# +==========+==============================+====================+================================+
# |        0 |                       0.0664 |           0.484636 |                         0.937  |
# |        1 |                       0.9429 |           0.123835 |                         0.9539 |
# +----------+------------------------------+--------------------+--------------------------------+

# %% [markdown]
# ### Setup Federation: Director & Envoys

# %% [markdown]
# Before we can deploy the experiment, let us create participants in Federation: Director and Envoys. As the Tutorial uses two collaborators we shall launch three participants:
# 1. Director: The central node in the Federation
# 2. Portland: The first envoy in the Federation
# 3. Seattle: The second envoy in the Federation
#
# The participants can be launched by following steps mentioned in [README]((https://github.com/securefederatedai/openfl/blob/develop/openfl-tutorials/experimental/workflow/FederatedRuntime/101_MNIST/README.md))

# %% [markdown]
# ### Deploy: FederatedRuntime

# %% [markdown]
# We now import and instantiate `FederatedRuntime` to enable deployment of experiment on distributed infrastructure. Initializing the `FederatedRuntime` requires following inputs to be provided by the user:
#
# - `director_info` – director information including fqdn of the director node, port, and certificate information
# - `collaborators` - names of the collaborators participating in experiment
# - `notebook_path`- path to this jupyter notebook

# %%
#| export

from openfl.experimental.workflow.runtime import FederatedRuntime

director_info = {
    'director_node_fqdn':'localhost',
    'director_port':50050,
}

federated_runtime = FederatedRuntime(
    collaborators=collaborator_names,
    director=director_info, 
    notebook_path='./101_MNIST_FederatedRuntime.ipynb'
)

# %% [markdown]
# Let us connect to federation & check if the envoys are connected to the director by using the `get_envoys` method of `FederatedRuntime`. If the participants are launched successful in previous step the status of `Portland` and `Seattle` should be displayed as `Online`

# %%
federated_runtime.get_envoys()
# Out:
# Status of Envoys connected to Federation at: 2025-05-11 19:34:15
#
# +----------+----------+---------------------+----------------------+-------------------+
# | Name     | Online   | Last Updated        | Experiment Running   | Experiment Name   |
# +==========+==========+=====================+======================+===================+
# | Portland | Yes      | 2025-05-11 19:34:11 | No                   | None              |
# +----------+----------+---------------------+----------------------+-------------------+
# | Seattle  | Yes      | 2025-05-11 19:34:12 | No                   | None              |
# +----------+----------+---------------------+----------------------+-------------------+
# ['Portland', 'Seattle']

# %% [markdown]
# Now that we have our distributed infrastructure ready, let us modify the flow runtime to `FederatedRuntime` instance and deploy the experiment.
#
# Progress of the flow is available on
# 1. Jupyter notebook: if `checkpoint` attribute of the flow object is set to `True`
# 2. Director and Envoy terminals

# %%
flflow.results = [] # clear results from previous run
flflow.runtime = federated_runtime
flflow.run()
# Out:
# New experimental workspace directory structure:
# generated_workspace
# ├── src
# │   ├── experiment.py
# │   ├── __init__.py
# │   └── __pycache__
# ├── requirements.txt
# ├── .workspace
# └── plan
#     ├── plan.yaml
#     └── defaults
#
# 3 directories, 6 files
# Archive created at /home/meet/openfl_meet/openfl/openfl-tutorials/experimental/workflow/FederatedRuntime/101_MNIST/workspace/experiment.zip
# ❌ Experiment 'FederatedFlow_TorchMNIST' was rejected by the Director.
# ❌ Flow execution stopped: FederatedRuntime: Experiment FederatedFlow_TorchMNIST failed to run due to error: Submission of experiment 'FederatedFlow_TorchMNIST' was rejected. Stopping execution.
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# File ~/miniconda3/envs/myenv_openfl/lib/python3.10/site-packages/openfl/experimental/workflow/interface/fl_spec.py:203, in FLSpec._run_federated(self)
#     202   print(f"\033❌ Experiment '{exp_name}' was rejected by the Director.\033")
# --> 203   raise Exception(f"Submission of experiment '{exp_name}' was rejected. Stopping execution.")
#     205 print(f"\033✅ Experiment '{exp_name}' approved and running.\033")
#
# Exception: Submission of experiment 'FederatedFlow_TorchMNIST' was rejected. Stopping execution.
#
# During handling of the above exception, another exception occurred:
#
# Exception                                 Traceback (most recent call last)
# Cell In[62], line 3
#       1 flflow.results = [] # clear results from previous run
#       2 flflow.runtime = federated_runtime
# ----> 3 flflow.run()
#
# File ~/miniconda3/envs/myenv_openfl/lib/python3.10/site-packages/openfl/experimental/workflow/interface/fl_spec.py:134, in FLSpec.run(self)
#     132     self._run_local()
#     133 elif str(self._runtime) == "FederatedRuntime":
# --> 134     self._run_federated()
#     135 else:
#     136     raise Exception("Runtime not implemented")
#
# File ~/miniconda3/envs/myenv_openfl/lib/python3.10/site-packages/openfl/experimental/workflow/interface/fl_spec.py:216, in FLSpec._run_federated(self)
#     213     self._update_from_flspec_obj(flspec)
#     215 except Exception as e:
# --> 216     raise Exception(
#     217         f"FederatedRuntime: Experiment {exp_name} failed to run due to error: {e}"
#     218     )
#
# Exception: FederatedRuntime: Experiment FederatedFlow_TorchMNIST failed to run due to error: Submission of experiment 'FederatedFlow_TorchMNIST' was rejected. Stopping execution.

# %% [markdown]
# Let us compare the simulation results from `LocalRuntime` and federation results from `FederatedRuntime`

# %%
headers = ["Rounds", "Agg Model Validation Score", "Local Train loss", "Local Model Validation score"]
print('********** Simulation results **********')
print(tabulate(simulation_results, headers=headers, tablefmt="outline"))

print('********** Federation results **********')
federation_results = flflow.results
print(tabulate(federation_results, headers=headers, tablefmt="outline"))
